# %%
from IPython.display import display

import sys
import os
import matplotlib.pyplot as plt
import numpy as np

sys.path.append("/home/lukas/MCMCSimulationLib/python_scripts/")
os.chdir("/home/lukas/LatticeModelImplementations/main_project")

# %%
from modes.load_headers import load_expectation_value_results

# %%
results = load_expectation_value_results("XYModelMetropolis")
# plt.plot(results["ExpectationValue"]["XYMagnetization"]["mean"])
plt.plot(results["ExpectationValue"]["XYMagnetization"]["mean"].index.values.astype(np.float32), results["ExpectationValue"]["XYMagnetization"]["mean"].values)
results
# Out:
# Measure     BootstrapError                           ExpectationValue  \
# Observable XYMagnetization                            XYMagnetization
# Statistics    fourthmoment         mean secondmoment     fourthmoment
# 0.050000       0.000186354   0.00110139  0.000579062       0.00835351
# 0.200000       0.000199253  0.000892947  0.000499387        0.0082776
# 0.350000       0.000144722  0.000786913  0.000406739        0.0079426
# 0.500000       0.000204609   0.00122214  0.000635958       0.00839593
# 0.650000       0.000207804  0.000953516  0.000546742        0.0086148
# 0.800000        0.00018345   0.00103388  0.000548878       0.00786982
# 0.950000       0.000174977  0.000940591  0.000504996       0.00838806
# 1.100000       0.000202812  0.000937715  0.000534808       0.00850682
# 1.250000       0.000179091   0.00097347  0.000517499       0.00799619
# 1.400000       0.000172762  0.000846178  0.000446975       0.00850459
# ...

# %%
results = load_expectation_value_results("XYModelHMC")
# plt.plot(results["ExpectationValue"]["XYMagnetization"]["mean"])
plt.plot(results["ExpectationValue"]["XYMagnetization"]["mean"].index.values.astype(np.float32), results["ExpectationValue"]["XYMagnetization"]["mean"].values)
results
# Out:
# Measure     BootstrapError                           ExpectationValue  \
# Observable XYMagnetization                            XYMagnetization
# Statistics    fourthmoment         mean secondmoment     fourthmoment
# 0.050000       3.39724e-05  0.000507157  0.000176399      0.000500079
# 0.200000       5.62395e-05  0.000645683  0.000246003       0.00200282
# 0.350000       0.000136208  0.000813796  0.000420035       0.00562222
# 0.500000       0.000464562   0.00154877   0.00104602        0.0282523
# 0.650000       0.000776379   0.00149425   0.00129987        0.0711662
# 0.800000       0.000985852   0.00138533   0.00137544         0.157529
# 0.950000        0.00115485  0.000991217   0.00123601         0.261028
# 1.100000        0.00114725  0.000748709   0.00105512         0.326841
# 1.250000        0.00103377  0.000628937  0.000914199          0.38361
# 1.400000        0.00090153  0.000497636  0.000750328         0.435865
# ...

# %%
results = load_expectation_value_results("PolySiteModelComplexLangevin")
# plt.plot(results["ExpectationValue"]["XYMagnetization"]["mean"])
results.transpose()
# Out:
#                                                              default
# Measure          Observable                Statistics
# BootstrapError   2ndMomentMean             fourthmoment   0.00889803
#                                            mean          0.000360573
#                                            secondmoment  0.000873261
# ExpectationValue 2ndMomentMean             fourthmoment      1.77606
#                                            max               6.26279
#                                            mean             0.460096
#                                            min                     0
#                                            secondmoment     0.521214
# BootstrapError   2ndMomentStateImag        fourthmoment      4.6e-09
#                                            mean          1.43354e-05
#                                            secondmoment   1.0048e-06
# ExpectationValue 2ndMomentStateImag        fourthmoment    3.806e-06
# ...

# %%
results = load_expectation_value_results("PolySiteModelCobridImagMonteCarlo")
# plt.plot(results["ExpectationValue"]["XYMagnetization"]["mean"])
results.transpose()
# Out:
#                                                  default
# Measure          Observable    Statistics
# BootstrapError   2ndMomentMean fourthmoment    0.0149035
#                                mean          0.000861017
#                                secondmoment   0.00185208
# ExpectationValue 2ndMomentMean fourthmoment       1.7274
#                                max               5.23079
#                                mean             0.462691
#                                min                     0
#                                secondmoment     0.523119
# BootstrapError   Mean          fourthmoment   0.00185208
#                                mean            0.0010619
#                                secondmoment  0.000861017
# ExpectationValue Mean          fourthmoment     0.523119
#                                max               2.28709
#                                mean          -0.00279504
#                                min                -2.286
# ...

# %%
results = load_expectation_value_results("PolySiteModelCobridMonteCarlo")
# plt.plot(results["ExpectationValue"]["XYMagnetization"]["mean"])
results.transpose()
# Out:
#                                                  default
# Measure          Observable    Statistics
# BootstrapError   2ndMomentMean fourthmoment      0.31945
#                                mean            0.0319147
#                                secondmoment    0.0688068
# ExpectationValue 2ndMomentMean fourthmoment      2.26089
#                                max                2.4815
#                                mean             0.582593
#                                min           0.000239104
#                                secondmoment     0.754845
# BootstrapError   Mean          fourthmoment    0.0688068
#                                mean            0.0388917
#                                secondmoment    0.0319147
# ExpectationValue Mean          fourthmoment     0.754845
#                                max               1.57528
#                                mean            0.0995025
#                                min              -1.47734
# ...

# %%
results = load_expectation_value_results("ScalarGaussianModel")
# plt.plot(results["ExpectationValue"]["XYMagnetization"]["mean"])
results.transpose()
# Out:
#                                                              default
# Measure          Observable                Statistics
# BootstrapError   2ndMomentMean             fourthmoment      2.52622
#                                            mean            0.0012956
#                                            secondmoment    0.0106753
# ExpectationValue 2ndMomentMean             fourthmoment       216.94
#                                            max               30.9465
#                                            mean              1.19958
#                                            min                     0
#                                            secondmoment      4.31716
# BootstrapError   2ndMomentStateImag        fourthmoment     0.426627
#                                            mean          0.000929832
#                                            secondmoment   0.00513876
# ExpectationValue 2ndMomentStateImag        fourthmoment      42.8702
# ...

# %%
results = load_expectation_value_results("ComplexScalarGaussianModel")
# plt.plot(results["ExpectationValue"]["XYMagnetization"]["mean"])
results.transpose()
# Out:
#                                                              default
# Measure          Observable                Statistics
# BootstrapError   2ndMomentMean             fourthmoment      1.93242
#                                            mean           0.00191084
#                                            secondmoment    0.0129493
# ExpectationValue 2ndMomentMean             fourthmoment      36.7743
#                                            max               19.2862
#                                            mean              0.74937
#                                            min                     0
#                                            secondmoment      1.69839
# BootstrapError   2ndMomentStateImag        fourthmoment    0.0164415
#                                            mean          0.000896839
#                                            secondmoment   0.00166644
# ExpectationValue 2ndMomentStateImag        fourthmoment     0.426233
# ...
